# %%
from datetime import datetime
name = "Adam"
location = "Praga"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Adam start programming at 2026-01-18 20:13:09.437514. Praga is the best city!

# %% [markdown]
# Моя перша програма

# %%
from datetime import datetime
name = "Adam"
location = "Praga"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Adam start programming at 2026-01-18 20:13:09.446776. Praga is the best city!
